# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the datasets
transactions_df = pd.read_csv('../data/updated_fraud_transactions.csv')
customers_df = pd.read_csv('../data/customer_dataset 1.csv')

# Display the first few rows of each dataset
print(transactions_df.head())
print(customers_df.head())
# Out:
#   Transaction ID            Timestamp  Sender Account ID Transaction Type  \
# 0         T00001  2023-08-14 08:37:07              10095         Transfer
# 1         T00002  2023-12-04 12:54:11              10098         Transfer
# 2         T00003  2023-07-09 23:16:11              10097           Credit
# 3         T00004  2023-06-26 07:04:39              10039           Credit
# 4         T00005  2023-09-28 02:40:56              10018            Debit
#
#   IN_OUT   Amount Recipient Bank  Fraud
# 0     In  4887.67          B0004      0
# 1     In  2371.33         B00010      0
# 2     In  4733.44          B0008      0
# 3     In  1544.12          B0005      0
# 4    Out  3978.04          B0004      0
#    Customer ID                Name  Age      Location  Gender Account Type  \
# 0        10001      Nimal Fernando   61        Jaffna  Female      Savings
# 1        10002  Sunil Samarasinghe   60        Jaffna   Other      Current
# 2        10003    Ruwan Jayasinghe   67         Galle   Other      Savings
# 3        10004      Lakshan Perera   19  Anuradhapura  Female      Savings
# 4        10005        Ruwan Kumara   52     Ratnapura   Other      Current
#
#    Device Count
# 0             5
# 1             3
# 2             1
# 3             5
# 4             4

# %%
# Check for missing values
print(transactions_df.isnull().sum())
print(customers_df.isnull().sum())

# Display basic statistics
print(transactions_df.describe())
print(customers_df.describe())

# Check the distribution of fraud vs non-fraud transactions
fraud_count = transactions_df['Fraud'].value_counts()
print(fraud_count)
plt.pie(fraud_count, labels=['Non-Fraud', 'Fraud'], autopct='%1.1f%%')
plt.title('Distribution of Fraud vs Non-Fraud Transactions')
plt.show()

# Convert timestamp to datetime
transactions_df['Timestamp'] = pd.to_datetime(transactions_df['Timestamp'])

# Extract time-based features
transactions_df['Hour'] = transactions_df['Timestamp'].dt.hour
transactions_df['Day'] = transactions_df['Timestamp'].dt.day
transactions_df['Month'] = transactions_df['Timestamp'].dt.month
transactions_df['DayOfWeek'] = transactions_df['Timestamp'].dt.dayofweek

# Encode categorical variables
transactions_df = pd.get_dummies(transactions_df, columns=['Transaction Type', 'IN_OUT', 'Recipient Bank'])
customers_df = pd.get_dummies(customers_df, columns=['Location', 'Gender', 'Account Type'])
# Out:
# Transaction ID       0
# Timestamp            0
# Sender Account ID    0
# Transaction Type     0
# IN_OUT               0
# Amount               0
# Recipient Bank       0
# Fraud                0
# dtype: int64
# Customer ID     0
# Name            0
# Age             0
# Location        0
# Gender          0
# Account Type    0
# Device Count    0
# dtype: int64
#        Sender Account ID         Amount          Fraud
# count      100000.000000  100000.000000  100000.000000
# mean        10050.554500    2619.425362       0.048530
# std            28.890176    2051.210808       0.214884
# min         10001.000000       2.468396       0.000000
# 25%         10026.000000    1205.750000       0.000000
# 50%         10051.000000    2481.825000       0.000000
# 75%         10076.000000    3776.750000       0.000000
# max         10100.000000   23017.641096       1.000000
#         Customer ID         Age  Device Count
# count    100.000000  100.000000    100.000000
# mean   10050.500000   51.030000      4.650000
# std       29.011492   17.536948      2.811862
# min    10001.000000   18.000000      1.000000
# 25%    10025.750000   36.750000      3.000000
# 50%    10050.500000   53.000000      4.000000
# 75%    10075.250000   64.250000      5.250000
# max    10100.000000   80.000000     11.000000
# Fraud
# 0    95147
# 1     4853
# Name: count, dtype: int64

# %%
# Merge transaction and customer data
merged_df = pd.merge(transactions_df, customers_df, left_on='Sender Account ID', right_on='Customer ID')

# Calculate transaction frequency for each customer
transaction_frequency = merged_df.groupby('Customer ID')['Transaction ID'].count().reset_index()
transaction_frequency.columns = ['Customer ID', 'Transaction_Frequency']
merged_df = pd.merge(merged_df, transaction_frequency, on='Customer ID')

# Calculate average transaction amount for each customer
avg_transaction_amount = merged_df.groupby('Customer ID')['Amount'].mean().reset_index()
avg_transaction_amount.columns = ['Customer ID', 'Avg_Transaction_Amount']
merged_df = pd.merge(merged_df, avg_transaction_amount, on='Customer ID')

# Create a feature for transaction amount relative to customer's average
merged_df['Amount_Relative_To_Average'] = merged_df['Amount'] / merged_df['Avg_Transaction_Amount']

# Drop unnecessary columns
merged_df = merged_df.drop(['Transaction ID', 'Timestamp', 'Sender Account ID', 'Customer ID', 'Name'], axis=1)

# %%
from imblearn.over_sampling import SMOTE

# Separate features and target
X = merged_df.drop('Fraud', axis=1)
y = merged_df['Fraud']

# Apply SMOTE
smote = SMOTE(random_state=42)
X_balanced, y_balanced = smote.fit_resample(X, y)

print("Shape of balanced dataset:", X_balanced.shape)
print("Distribution of target variable:\n", pd.Series(y_balanced).value_counts(normalize=True))
# Out:
# Shape of balanced dataset: (190294, 42)
# Distribution of target variable:
#  Fraud
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
from sklearn.feature_selection import mutual_info_classif

# Calculate correlation matrix
corr_matrix = X_balanced.corr()

# Plot correlation heatmap
plt.figure(figsize=(20, 16))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# Calculate mutual information scores
mi_scores = mutual_info_classif(X_balanced, y_balanced)
mi_scores = pd.Series(mi_scores, index=X_balanced.columns).sort_values(ascending=False)

# Plot mutual information scores
plt.figure(figsize=(10, 6))
mi_scores.plot(kind='bar')
plt.title('Feature Importance (Mutual Information)')
plt.ylabel('Mutual Information Score')
plt.tight_layout()
plt.show()

# Select top features based on mutual information scores
top_features = mi_scores.nlargest(15).index.tolist()
X_selected = X_balanced[top_features]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_selected, y_balanced, test_size=0.2, random_state=42)

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train_scaled, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/50
# 2024-10-08 06:36:27.979552: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 3806/3806 [==============================] - 3s 625us/step - loss: 0.1537 - accuracy: 0.9329 - val_loss: 0.1100 - val_accuracy: 0.9486
# Epoch 2/50
# 3806/3806 [==============================] - 2s 587us/step - loss: 0.1159 - accuracy: 0.9470 - val_loss: 0.1044 - val_accuracy: 0.9512
# Epoch 3/50
# 3806/3806 [==============================] - 2s 599us/step - loss: 0.1109 - accuracy: 0.9490 - val_loss: 0.1023 - val_accuracy: 0.9529
# Epoch 4/50
# 3806/3806 [==============================] - 2s 654us/step - loss: 0.1092 - accuracy: 0.9499 - val_loss: 0.1022 - val_accuracy: 0.9526
# Epoch 5/50
# 3806/3806 [==============================] - 2s 568us/step - loss: 0.1078 - accuracy: 0.9507 - val_loss: 0.1020 - val_accuracy: 0.9537
# Epoch 6/50
# 3806/3806 [==============================] - 2s 580us/step - loss: 0.1008 - accuracy: 0.9543 - val_loss: 0.0979 - val_accuracy: 0.9566
# Epoch 45/50
# 3806/3806 [==============================] - 2s 587us/step - loss: 0.1005 - accuracy: 0.9542 - val_loss: 0.0970 - val_accuracy: 0.9570
# Epoch 46/50
# 3806/3806 [==============================] - 2s 580us/step - loss: 0.1004 - accuracy: 0.9546 - val_loss: 0.0980 - val_accuracy: 0.9570
# Epoch 47/50
# 3806/3806 [==============================] - 2s 597us/step - loss: 0.1004 - accuracy: 0.9544 - val_loss: 0.0985 - val_accuracy: 0.9569
# Epoch 48/50
# 3806/3806 [==============================] - 2s 617us/step - loss: 0.1002 - accuracy: 0.9549 - val_loss: 0.0971 - val_accuracy: 0.9572
# Epoch 49/50
# 3806/3806 [==============================] - 2s 588us/step - loss: 0.1006 - accuracy: 0.9545 - val_loss: 0.0977 - val_accuracy: 0.9575
# Epoch 50/50
# 3806/3806 [==============================] - 2s 604us/step - loss: 0.1003 - accuracy: 0.9545 - val_loss: 0.0966 - val_accuracy: 0.9572

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Make predictions
y_pred = model.predict(X_test_scaled)
y_pred_classes = (y_pred > 0.5).astype(int)

# Print classification report
print(classification_report(y_test, y_pred_classes))

# Plot confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# Calculate ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred)
print(f"ROC AUC Score: {roc_auc}")

# Plot training history
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# 1190/1190 [==============================] - 0s 262us/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96     19026
#            1       0.95      0.96      0.96     19033
#
#     accuracy                           0.96     38059
#    macro avg       0.96      0.96      0.96     38059
# weighted avg       0.96      0.96      0.96     38059
# ROC AUC Score: 0.9939860534461302

# %%
import keras_tuner as kt

def build_model(hp):
    model = Sequential()
    model.add(Dense(units=hp.Int('units_1', min_value=32, max_value=512, step=32),
                    activation='relu', input_shape=(X_train.shape[1],)))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.0, max_value=0.5, step=0.1)))
    
    for i in range(hp.Int('num_layers', 1, 5)):
        model.add(Dense(units=hp.Int(f'units_{i+2}', min_value=32, max_value=512, step=32),
                        activation='relu'))
        model.add(Dropout(hp.Float(f'dropout_{i+2}', min_value=0.0, max_value=0.5, step=0.1)))
    
    model.add(Dense(1, activation='sigmoid'))
    
    model.compile(
        optimizer=Adam(hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log')),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

tuner = kt.Hyperband(
    build_model,
    objective='val_accuracy',
    max_epochs=50,
    factor=3,
    directory='my_dir',
    project_name='fraud_detection'
)

tuner.search(X_train_scaled, y_train, epochs=50, validation_split=0.2)

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of layers: {best_hps.get('num_layers')}
The optimal learning rate for the optimizer is: {best_hps.get('learning_rate'):.4f}
""")

# Build the model with the optimal hyperparameters and train it on the data
model = tuner.hypermodel.build(best_hps)
history = model.fit(X_train_scaled, y_train, epochs=50, validation_split=0.2)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test)
print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Trial 90 Complete [00h 08m 08s]
# val_accuracy: 0.9627549648284912
#
# Best val_accuracy So Far: 0.9685683250427246
# Total elapsed time: 02h 18m 46s
#
# The hyperparameter search is complete. The optimal number of layers: 3
# The optimal learning rate for the optimizer is: 0.0002
#
# Epoch 1/50
# 3806/3806 [==============================] - 10s 2ms/step - loss: 0.1281 - accuracy: 0.9427 - val_loss: 0.1076 - val_accuracy: 0.9501
# Epoch 2/50
# 3806/3806 [==============================] - 12s 3ms/step - loss: 0.1071 - accuracy: 0.9508 - val_loss: 0.1021 - val_accuracy: 0.9534
# Epoch 3/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.1042 - accuracy: 0.9523 - val_loss: 0.1026 - val_accuracy: 0.9528
# Epoch 4/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.1019 - accuracy: 0.9538 - val_loss: 0.1002 - val_accuracy: 0.9539
# Epoch 5/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.1001 - accuracy: 0.9542 - val_loss: 0.0971 - val_accuracy: 0.9560
# Epoch 6/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0983 - accuracy: 0.9553 - val_loss: 0.0975 - val_accuracy: 0.9556
# Epoch 7/50
# 3806/3806 [==============================] - 11s 3ms/step - loss: 0.0969 - accuracy: 0.9558 - val_loss: 0.0953 - val_accuracy: 0.9562
# Epoch 8/50
# 3806/3806 [==============================] - 11s 3ms/step - loss: 0.0958 - accuracy: 0.9569 - val_loss: 0.0943 - val_accuracy: 0.9565
# Epoch 9/50
# 3806/3806 [==============================] - 11s 3ms/step - loss: 0.0938 - accuracy: 0.9580 - val_loss: 0.0942 - val_accuracy: 0.9581
# Epoch 10/50
# 3806/3806 [==============================] - 11s 3ms/step - loss: 0.0932 - accuracy: 0.9582 - val_loss: 0.0929 - val_accuracy: 0.9583
# Epoch 11/50
# 3806/3806 [==============================] - 12s 3ms/step - loss: 0.0922 - accuracy: 0.9586 - val_loss: 0.0936 - val_accuracy: 0.9588
# Epoch 12/50
# 3806/3806 [==============================] - 12s 3ms/step - loss: 0.0905 - accuracy: 0.9595 - val_loss: 0.0918 - val_accuracy: 0.9591
# Epoch 13/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0890 - accuracy: 0.9605 - val_loss: 0.0905 - val_accuracy: 0.9603
# Epoch 14/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0880 - accuracy: 0.9612 - val_loss: 0.0901 - val_accuracy: 0.9607
# Epoch 15/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0868 - accuracy: 0.9615 - val_loss: 0.0896 - val_accuracy: 0.9619
# Epoch 16/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0862 - accuracy: 0.9621 - val_loss: 0.0891 - val_accuracy: 0.9617
# Epoch 17/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0844 - accuracy: 0.9625 - val_loss: 0.0887 - val_accuracy: 0.9624
# Epoch 18/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0838 - accuracy: 0.9632 - val_loss: 0.0880 - val_accuracy: 0.9623
# Epoch 19/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0828 - accuracy: 0.9640 - val_loss: 0.0898 - val_accuracy: 0.9608
# Epoch 20/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0818 - accuracy: 0.9642 - val_loss: 0.0861 - val_accuracy: 0.9627
# Epoch 21/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0810 - accuracy: 0.9642 - val_loss: 0.0862 - val_accuracy: 0.9626
# Epoch 22/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0804 - accuracy: 0.9646 - val_loss: 0.0864 - val_accuracy: 0.9619
# Epoch 23/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0803 - accuracy: 0.9646 - val_loss: 0.0872 - val_accuracy: 0.9634
# Epoch 24/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0793 - accuracy: 0.9650 - val_loss: 0.0842 - val_accuracy: 0.9638
# Epoch 25/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0780 - accuracy: 0.9657 - val_loss: 0.0840 - val_accuracy: 0.9641
# Epoch 26/50
# 3806/3806 [==============================] - 8s 2ms/step - loss: 0.0779 - accuracy: 0.9659 - val_loss: 0.0833 - val_accuracy: 0.9654
# Epoch 27/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0766 - accuracy: 0.9670 - val_loss: 0.0844 - val_accuracy: 0.9650
# Epoch 28/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0757 - accuracy: 0.9670 - val_loss: 0.0838 - val_accuracy: 0.9650
# Epoch 29/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0750 - accuracy: 0.9678 - val_loss: 0.0829 - val_accuracy: 0.9655
# Epoch 30/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0750 - accuracy: 0.9675 - val_loss: 0.0835 - val_accuracy: 0.9652
# Epoch 31/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0745 - accuracy: 0.9679 - val_loss: 0.0850 - val_accuracy: 0.9661
# Epoch 32/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0738 - accuracy: 0.9682 - val_loss: 0.0822 - val_accuracy: 0.9655
# Epoch 33/50
# 3806/3806 [==============================] - 11s 3ms/step - loss: 0.0726 - accuracy: 0.9693 - val_loss: 0.0817 - val_accuracy: 0.9668
# Epoch 34/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0724 - accuracy: 0.9691 - val_loss: 0.0854 - val_accuracy: 0.9643
# Epoch 35/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0722 - accuracy: 0.9691 - val_loss: 0.0828 - val_accuracy: 0.9653
# Epoch 36/50
# 3806/3806 [==============================] - 11s 3ms/step - loss: 0.0711 - accuracy: 0.9700 - val_loss: 0.0818 - val_accuracy: 0.9661
# Epoch 37/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0708 - accuracy: 0.9696 - val_loss: 0.0820 - val_accuracy: 0.9662
# Epoch 38/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0704 - accuracy: 0.9698 - val_loss: 0.0839 - val_accuracy: 0.9664
# Epoch 39/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0695 - accuracy: 0.9703 - val_loss: 0.0831 - val_accuracy: 0.9669
# Epoch 40/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0697 - accuracy: 0.9704 - val_loss: 0.0832 - val_accuracy: 0.9672
# Epoch 41/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0687 - accuracy: 0.9707 - val_loss: 0.0897 - val_accuracy: 0.9659
# Epoch 42/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0681 - accuracy: 0.9715 - val_loss: 0.0817 - val_accuracy: 0.9680
# Epoch 43/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0679 - accuracy: 0.9711 - val_loss: 0.0832 - val_accuracy: 0.9676
# Epoch 44/50
# 3806/3806 [==============================] - 8s 2ms/step - loss: 0.0679 - accuracy: 0.9714 - val_loss: 0.0862 - val_accuracy: 0.9675
# Epoch 45/50
# 3806/3806 [==============================] - 8s 2ms/step - loss: 0.0668 - accuracy: 0.9723 - val_loss: 0.0806 - val_accuracy: 0.9680
# Epoch 46/50
# 3806/3806 [==============================] - 8s 2ms/step - loss: 0.0671 - accuracy: 0.9719 - val_loss: 0.0818 - val_accuracy: 0.9689
# Epoch 47/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0661 - accuracy: 0.9725 - val_loss: 0.0821 - val_accuracy: 0.9674
# Epoch 48/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0668 - accuracy: 0.9715 - val_loss: 0.0831 - val_accuracy: 0.9680
# Epoch 49/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0649 - accuracy: 0.9729 - val_loss: 0.0800 - val_accuracy: 0.9694
# Epoch 50/50
# 3806/3806 [==============================] - 8s 2ms/step - loss: 0.0653 - accuracy: 0.9723 - val_loss: 0.0795 - val_accuracy: 0.9689
# 1190/1190 [==============================] - 1s 570us/step - loss: 0.0834 - accuracy: 0.9667
# Test accuracy: 0.9667

# %%
print("Best Hyperparameters:")
for param, value in best_hps.values.items():
    print(f"{param}: {value}")
# Out:
# Best Hyperparameters:
# units_1: 448
# dropout_1: 0.0
# num_layers: 3
# units_2: 384
# dropout_2: 0.30000000000000004
# learning_rate: 0.00023551176889278282
# units_3: 480
# dropout_3: 0.4
# units_4: 128
# dropout_4: 0.1
# units_5: 64
# dropout_5: 0.2
# units_6: 128
# dropout_6: 0.0
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0074

# %%
# Build the final model with the best hyperparameters
final_model = tuner.hypermodel.build(best_hps)

# Train the model
history = final_model.fit(
    X_train_scaled, y_train,
    epochs=50,  # You might want to increase this for the final model
    batch_size=32,  # Adjust if the best hyperparameters included a different batch size
    validation_split=0.2,
    verbose=1
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.1291 - accuracy: 0.9425 - val_loss: 0.1066 - val_accuracy: 0.9497
# Epoch 2/50
# 3806/3806 [==============================] - 11s 3ms/step - loss: 0.1074 - accuracy: 0.9510 - val_loss: 0.1021 - val_accuracy: 0.9522
# Epoch 3/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.1037 - accuracy: 0.9530 - val_loss: 0.1005 - val_accuracy: 0.9527
# Epoch 4/50
# 3806/3806 [==============================] - 11s 3ms/step - loss: 0.1015 - accuracy: 0.9535 - val_loss: 0.1006 - val_accuracy: 0.9533
# Epoch 5/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.1002 - accuracy: 0.9546 - val_loss: 0.0979 - val_accuracy: 0.9556
# Epoch 6/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0989 - accuracy: 0.9554 - val_loss: 0.0968 - val_accuracy: 0.9566
# Epoch 7/50
# 3806/3806 [==============================] - 10s 2ms/step - loss: 0.0970 - accuracy: 0.9563 - val_loss: 0.0956 - val_accuracy: 0.9564
# Epoch 8/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0962 - accuracy: 0.9569 - val_loss: 0.0959 - val_accuracy: 0.9568
# Epoch 9/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0943 - accuracy: 0.9580 - val_loss: 0.0952 - val_accuracy: 0.9588
# Epoch 10/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0933 - accuracy: 0.9586 - val_loss: 0.0948 - val_accuracy: 0.9577
# Epoch 11/50
# 3806/3806 [==============================] - 11s 3ms/step - loss: 0.0924 - accuracy: 0.9594 - val_loss: 0.0935 - val_accuracy: 0.9583
# Epoch 12/50
# 3806/3806 [==============================] - 10s 2ms/step - loss: 0.0906 - accuracy: 0.9599 - val_loss: 0.0930 - val_accuracy: 0.9578
# Epoch 13/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0899 - accuracy: 0.9599 - val_loss: 0.0915 - val_accuracy: 0.9598
# Epoch 14/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0886 - accuracy: 0.9609 - val_loss: 0.0906 - val_accuracy: 0.9605
# Epoch 15/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0875 - accuracy: 0.9617 - val_loss: 0.0896 - val_accuracy: 0.9606
# Epoch 16/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0863 - accuracy: 0.9624 - val_loss: 0.0891 - val_accuracy: 0.9619
# Epoch 17/50
# 3806/3806 [==============================] - 11s 3ms/step - loss: 0.0855 - accuracy: 0.9625 - val_loss: 0.0891 - val_accuracy: 0.9611
# Epoch 18/50
# 3806/3806 [==============================] - 11s 3ms/step - loss: 0.0845 - accuracy: 0.9631 - val_loss: 0.0881 - val_accuracy: 0.9623
# Epoch 19/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0832 - accuracy: 0.9634 - val_loss: 0.0883 - val_accuracy: 0.9632
# Epoch 20/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0832 - accuracy: 0.9638 - val_loss: 0.0875 - val_accuracy: 0.9617
# Epoch 21/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0815 - accuracy: 0.9645 - val_loss: 0.0886 - val_accuracy: 0.9623
# Epoch 22/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0805 - accuracy: 0.9651 - val_loss: 0.0862 - val_accuracy: 0.9629
# Epoch 23/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0803 - accuracy: 0.9653 - val_loss: 0.0870 - val_accuracy: 0.9641
# Epoch 24/50
# 3806/3806 [==============================] - 11s 3ms/step - loss: 0.0796 - accuracy: 0.9652 - val_loss: 0.0861 - val_accuracy: 0.9646
# Epoch 25/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0790 - accuracy: 0.9663 - val_loss: 0.0870 - val_accuracy: 0.9629
# Epoch 26/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0778 - accuracy: 0.9664 - val_loss: 0.0861 - val_accuracy: 0.9652
# Epoch 27/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0766 - accuracy: 0.9674 - val_loss: 0.0853 - val_accuracy: 0.9655
# Epoch 28/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0760 - accuracy: 0.9673 - val_loss: 0.0859 - val_accuracy: 0.9655
# Epoch 29/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0750 - accuracy: 0.9680 - val_loss: 0.0842 - val_accuracy: 0.9647
# Epoch 30/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0748 - accuracy: 0.9680 - val_loss: 0.0853 - val_accuracy: 0.9646
# Epoch 31/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0742 - accuracy: 0.9680 - val_loss: 0.0825 - val_accuracy: 0.9663
# Epoch 32/50
# 3806/3806 [==============================] - 10s 2ms/step - loss: 0.0743 - accuracy: 0.9683 - val_loss: 0.0831 - val_accuracy: 0.9665
# Epoch 33/50
# 3806/3806 [==============================] - 11s 3ms/step - loss: 0.0736 - accuracy: 0.9686 - val_loss: 0.0829 - val_accuracy: 0.9666
# Epoch 34/50
# 3806/3806 [==============================] - 11s 3ms/step - loss: 0.0728 - accuracy: 0.9693 - val_loss: 0.0825 - val_accuracy: 0.9666
# Epoch 35/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0709 - accuracy: 0.9703 - val_loss: 0.0835 - val_accuracy: 0.9657
# Epoch 36/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0716 - accuracy: 0.9698 - val_loss: 0.0827 - val_accuracy: 0.9662
# Epoch 37/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0713 - accuracy: 0.9697 - val_loss: 0.0844 - val_accuracy: 0.9672
# Epoch 38/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0705 - accuracy: 0.9702 - val_loss: 0.0801 - val_accuracy: 0.9678
# Epoch 39/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0694 - accuracy: 0.9707 - val_loss: 0.0812 - val_accuracy: 0.9670
# Epoch 40/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0692 - accuracy: 0.9707 - val_loss: 0.0823 - val_accuracy: 0.9681
# Epoch 41/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0681 - accuracy: 0.9715 - val_loss: 0.0863 - val_accuracy: 0.9667
# Epoch 42/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0686 - accuracy: 0.9713 - val_loss: 0.0815 - val_accuracy: 0.9668
# Epoch 43/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0676 - accuracy: 0.9716 - val_loss: 0.0800 - val_accuracy: 0.9682
# Epoch 44/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0674 - accuracy: 0.9719 - val_loss: 0.0810 - val_accuracy: 0.9683
# Epoch 45/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0664 - accuracy: 0.9722 - val_loss: 0.0813 - val_accuracy: 0.9667
# Epoch 46/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0663 - accuracy: 0.9723 - val_loss: 0.0830 - val_accuracy: 0.9687
# Epoch 47/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0661 - accuracy: 0.9724 - val_loss: 0.0804 - val_accuracy: 0.9682
# Epoch 48/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0654 - accuracy: 0.9726 - val_loss: 0.0816 - val_accuracy: 0.9685
# Epoch 49/50
# 3806/3806 [==============================] - 10s 3ms/step - loss: 0.0657 - accuracy: 0.9724 - val_loss: 0.0819 - val_accuracy: 0.9692
# Epoch 50/50
# 3806/3806 [==============================] - 9s 2ms/step - loss: 0.0649 - accuracy: 0.9733 - val_loss: 0.0793 - val_accuracy: 0.9691

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

# Make predictions
y_pred = final_model.predict(X_test_scaled)
y_pred_classes = (y_pred > 0.5).astype(int)

# Print classification report
print(classification_report(y_test, y_pred_classes))

# Plot confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# Plot ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(10, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# Plot training history
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 1190/1190 [==============================] - 1s 859us/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97     19026
#            1       0.96      0.97      0.97     19033
#
#     accuracy                           0.97     38059
#    macro avg       0.97      0.97      0.97     38059
# weighted avg       0.97      0.97      0.97     38059

# %%
final_model.save('fraud_detection_model.h5')

# %%
def predict_fraud(new_data):
    # Preprocess the new data (apply the same preprocessing steps as before)
    # This is a placeholder - you'll need to implement the actual preprocessing steps
    preprocessed_data = preprocess_new_data(new_data)
    
    # Scale the data
    scaled_data = scaler.transform(preprocessed_data)
    
    # Make predictions
    predictions = final_model.predict(scaled_data)
    
    return predictions

# %%
# Example usage:
new_transactions = pd.read_csv('new_transactions.csv')
fraud_probabilities = predict_fraud(new_transactions)
print(fraud_probabilities)
